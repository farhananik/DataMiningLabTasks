# %%
import pandas as pd

# %%
df = pd.read_csv('rainfall.csv')

# %%
df.head(10)
# Out:
#    day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# 0    1    1025.9     19.9         18.3     16.8      13.1        72     49
# 1    2    1022.0     21.7         18.9     17.2      15.6        81     83
# 2    3    1019.7     20.3         19.3     18.0      18.4        95     91
# 3    4    1018.9     22.3         20.6     19.1      18.8        90     88
# 4    5    1015.9     21.3         20.7     20.2      19.9        95     81
# 5    6    1018.8     24.3         20.9     19.2      18.0        84     51
# 6    7    1021.8     21.4         18.8     17.0      15.0        79     56
# 7    8    1020.8     21.0         18.4     16.5      14.4        78     28
# 8    9    1020.6     18.9         18.1     17.1      14.3        78     79
# 9   10    1017.5     18.5         18.0     17.2      15.5        85     91
#
#   rainfall  sunshine  winddirection  windspeed
# 0      yes       9.3           80.0       26.3
# 1      yes       0.6           50.0       15.3
# ...

# %%
df.tail(10)
# Out:
#      day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# 356   22    1020.3     20.6         19.9     18.7      17.6        87     88
# 357   23    1017.8     22.3         21.1     19.8      19.6        91     79
# 358   24    1016.8     24.7         22.3     21.1      20.7        91     70
# 359   25    1020.4     21.4         18.2     16.1      13.5        75     89
# 360   26    1020.6     19.7         17.9     16.9      13.3        74     87
# 361   27    1022.7     18.8         17.7     16.9      15.0        84     90
# 362   28    1026.6     18.6         17.3     16.3      12.8        75     85
# 363   29    1025.9     18.9         17.7     16.4      13.3        75     78
# 364   30    1025.3     19.2         17.3     15.2      13.3        78     86
# 365   31    1026.4     20.5         17.8     15.5      13.0        74     66
#
#     rainfall  sunshine  winddirection  windspeed
# 356      yes       0.3           60.0       27.3
# ...

# %%
print(df.columns)
# Out:
# Index(['day', 'pressure', 'maxtemp', 'temparature', 'mintemp', 'dewpoint',
#        'humidity', 'cloud', 'rainfall', 'sunshine', 'winddirection',
#        'windspeed'],
#       dtype='object')

# %%
df.dtypes
# Out:
# day                int64
# pressure         float64
# maxtemp          float64
# temparature      float64
# mintemp          float64
# dewpoint         float64
# humidity           int64
# cloud              int64
# rainfall          object
# sunshine         float64
# winddirection    float64
# windspeed        float64
# dtype: object

# %%
df['sunshine']=df['sunshine'].replace(0.0,float('Nan'))

# %%
df
# Out:
#      day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# 0      1    1025.9     19.9         18.3     16.8      13.1        72     49
# 1      2    1022.0     21.7         18.9     17.2      15.6        81     83
# 2      3    1019.7     20.3         19.3     18.0      18.4        95     91
# 3      4    1018.9     22.3         20.6     19.1      18.8        90     88
# 4      5    1015.9     21.3         20.7     20.2      19.9        95     81
# ..   ...       ...      ...          ...      ...       ...       ...    ...
# 361   27    1022.7     18.8         17.7     16.9      15.0        84     90
# 362   28    1026.6     18.6         17.3     16.3      12.8        75     85
# 363   29    1025.9     18.9         17.7     16.4      13.3        75     78
# 364   30    1025.3     19.2         17.3     15.2      13.3        78     86
# 365   31    1026.4     20.5         17.8     15.5      13.0        74     66
#
# ...

# %%
print(df.dropna())
# Out:
#      day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# 0      1    1025.9     19.9         18.3     16.8      13.1        72     49
# 1      2    1022.0     21.7         18.9     17.2      15.6        81     83
# 3      4    1018.9     22.3         20.6     19.1      18.8        90     88
# 5      6    1018.8     24.3         20.9     19.2      18.0        84     51
# 6      7    1021.8     21.4         18.8     17.0      15.0        79     56
# ..   ...       ...      ...          ...      ...       ...       ...    ...
# 360   26    1020.6     19.7         17.9     16.9      13.3        74     87
# 362   28    1026.6     18.6         17.3     16.3      12.8        75     85
# 363   29    1025.9     18.9         17.7     16.4      13.3        75     78
# 364   30    1025.3     19.2         17.3     15.2      13.3        78     86
# 365   31    1026.4     20.5         17.8     15.5      13.0        74     66
#
# ...

# %%
df.drop(columns=['winddirection', 'windspeed'])
# Out:
#      day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# 0      1    1025.9     19.9         18.3     16.8      13.1        72     49
# 1      2    1022.0     21.7         18.9     17.2      15.6        81     83
# 2      3    1019.7     20.3         19.3     18.0      18.4        95     91
# 3      4    1018.9     22.3         20.6     19.1      18.8        90     88
# 4      5    1015.9     21.3         20.7     20.2      19.9        95     81
# ..   ...       ...      ...          ...      ...       ...       ...    ...
# 361   27    1022.7     18.8         17.7     16.9      15.0        84     90
# 362   28    1026.6     18.6         17.3     16.3      12.8        75     85
# 363   29    1025.9     18.9         17.7     16.4      13.3        75     78
# 364   30    1025.3     19.2         17.3     15.2      13.3        78     86
# 365   31    1026.4     20.5         17.8     15.5      13.0        74     66
#
#     rainfall  sunshine
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.scatter(df.humidity,df.cloud)

# %%
df.drop(df.columns.difference(['humidity','cloud']), 1, inplace=True)

# %%
df
# Out:
#      humidity  cloud
# 0          72     49
# 1          81     83
# 2          95     91
# 3          90     88
# 4          95     81
# ..        ...    ...
# 361        84     90
# 362        75     85
# 363        75     78
# 364        78     86
# 365        74     66
#
# [366 rows x 2 columns]

# %%
a = np.cov(df1.humidity,df1.cloud)

# %%
print(a)
# Out:
# [[101.25330489 143.77713152]
#  [143.77713152 475.15332734]]

# %%
def pearson(x,y):
    correlation_matrix=np.corrcoef(x,y)
    return correlation_matrix[0,1]

# %%
r = pearson(df1.humidity,df1.cloud)

# %%
print(r)
# Out:
# 0.6554934006734929
